# %%
import os
import snowballstemmer
import string
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from pathlib import Path

# %%
def preprocess_text(text):
    print("Original text:")
    print(text)
    
    # Removes punctuation marks
    text = text.translate(str.maketrans(string.punctuation, ' ' * len(string.punctuation)))
    
    # Converts all words in the text to lowercase
    text = text.lower()
    
    # Turkish stemming process
    stemmer = snowballstemmer.TurkishStemmer()
    tokens = text.split()
    stemmed_words = [stemmer.stemWord(word) for word in tokens]
    
    # Combines the preprocessed text
    processed_text = " ".join(stemmed_words)
    
    print("Processed text:")
    print(processed_text)
    print("\n")
    
    return processed_text

# %%
def load_data(path):
    
    data = []
    labels = []
    for label, folder in enumerate(['negative', 'neutral', 'positive']):
        folder_path = os.path.join(path, folder)
        for filename in os.listdir(folder_path):
            with open(os.path.join(folder_path, filename), 'r') as file:
                data.append(preprocess_text(file.read()))
                labels.append(label + 1)  
    return data, labels

# %%
def tfidf_knn(data, labels, k=8):
    print("Training TF-IDF and KNN model...")
    
    # TF-IDF vectorization
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(data)
    
    # Applying KNN model with Cosine metric
    knn = KNeighborsClassifier(n_neighbors=k, metric='cosine')
    knn.fit(tfidf_matrix, labels)
    
    # Making predictions
    predictions = knn.predict(tfidf_matrix)
    
    # Calculating TP, FP, FN using Confusion Matrix
    cm = confusion_matrix(labels, predictions)
    
    class_names = ['negative', 'neutral', 'positive']
    
    # Printing TP, FP, FN values for each class
    for i, class_name in enumerate(class_names):
        TP = cm[i, i]
        FN = cm[i, :].sum() - TP
        FP = cm[:, i].sum() - TP
        print(f"Class: {class_name} (Label: {i+1})")
        print(f"  TP: {TP}, FN: {FN}, FP: {FP}")
    
    # Calculating F1 score
    scores = cross_val_score(knn, tfidf_matrix, labels, cv=10, scoring='f1_macro')
    
    return scores.mean()

# %%
def tfidf_to_csv(data, labels, output_file="tfidf_output.csv"):
    # TF-IDF vectorization
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(data)

    # Convert TF-IDF matrix to DataFrame
    tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())

    # Add class labels as a new column
    tfidf_df['Class'] = labels

    # Save the DataFrame to a CSV file
    tfidf_df.to_csv(output_file)

    print(f"TF-IDF table saved to {output_file}")

# %%
if __name__ == "__main__":
    folder_path = r"C:\Users\İBRAHİM HALİL\Assignment\Raw_Texts"
    data, labels = load_data(folder_path)
    
    tfidf_to_csv(data, labels, output_file="tfidf_output.csv")

    # TF-IDF ve KNN modelini çalıştır ve başarı skorunu yazdır
    tfidf_knn_score = tfidf_knn(data, labels, k=8)
    print(f"TF-IDF ve KNN modeli başarı skoru (F1-macro): {tfidf_knn_score:.4f}")
# Out:
# Original text:
# hayir!
# Processed text:
# hayir
#
#
# Original text:
# #turkcell adinda bir telefon operatoru var.deli dumrul dan besbin beter.Para carpmanin adi #turkcell olmus.eline ver kolunu kurtaramiyorsun
# Processed text:
# turkcell ad bir telefo operator var del dumrul dan besp beter par carpman adi turkcell olmus el ver kol kurtaramiyor
#
#
# Original text:
# Dileğim; SuperOnline, Turkcell, TTNET vb. firmaların 2012'de "sizi arayacağız" demek yerine direk burdan cevap vermesi şeklinde. #hope #2012
# Processed text:
# dilek superonl turkcell ttnet vb firma 2012 de siz arayacak demek yer direk bur cevap vermes şekl hope 2012
#
#
# Original text:
# Mesaj hakkı yapamıyorum,turkcell yok olsun istiyorum şuan
# Processed text:
# mesaj hakkı yapamıyor turkcell yok ol istiyor şuan
#
#
# Original text:
# Turksel amca yapmiyo artik sana oyle kiyaaklar kankı
# Processed text:
# turksel am yapmiyo artik sa oyle kiyaak kankı
#
#
# Original text:
# TÜRKCELL SÜPERONLİNE ANADOLU YAKASINDAKİ SORUNUNU 2012 ÇÖZER Mİ ACABA.
# Processed text:
# türkcell süperonli̇ne anadol yakasindaki̇ sorun 2012 çözer mi̇ acap
#
#
# Original text:
# #Turkcell umarım bundan sonra kafasına sarı anten geçiren,mıy mıy konuşan v ayağına inşaat çizmesi giyen çocukları kullanmazsın reklmlarında
# Processed text:
# turkcell umar p sonra kafa sar ante geçire mıy mıy konuşa v ayak inşaat çizmes giye çocuk kullanmaz reklm
#
#
# Original text:
# sendemi birütüsss yha :( türksel görünümlü şahin gitti kontürler :/
# Processed text:
# sende birütüsss yha türksel görünümlü şah git kontür
#
#
# Original text:
# 28.11.2011 de başlayan oturumu 01.01.2012 00:34 de kapatıp ilgili kotayı Ocak 2012 ye ekleyen superonline ı buradan alkışlarla kınıyorum.
# Processed text:
# 28 11 2011 de başlaya otur 01 01 2012 00 34 de kapatıp ilgil kota ocak 2012 ye ekleye superonl ı bura alkış kınıyor
#
#
# Original text:
# Bu gece saat 00.00'da mesaj atayımda sevgılısı attı sansın gerızekalı -Turkcell
# Processed text:
# bu geç saat 00 00 da mesaj atay sevgılıs at sa gerızekal turkcell
#
#
# Original text:
# bir hafta icerisinde kurulum yapacaktiniz,araya bayram tatili girdi o zamandan bu zamana ne arayan ne gelen var
# Processed text:
# bir haf iceri kurul yapacakt ara bayra tatil gir o zama bu zama ne araya ne gele var
#
#
# Original text:
# ısık hızında oldugunu ıddıa ettıklerı ınternetı 8 gunde baglayamıyorlar
# Processed text:
# ısık hız oldugu ıddıa ettık ınternet 8 gunde baglayamıyor
#
#
# Original text:
# +Turkcell'i kazıkladım.  -Nasıl yaptın kanka?  +SMS yaptım seneye bitiyo. :D
# Processed text:
#  turkcell i kazıkladı nasıl yap kanka sms yap sene bitiyo d
#
#
# Original text:
# #superonline yine birincil dns sunucusu hatasi verdi baglanamiyorum
# Processed text:
# superonl y birincil dns sunucus hatasi ver baglanamiyor
#
#
# Original text:
# iPhone 4S kampanyan çok pahalı be Turkcell'im. Bi' kerede demediniz ki al ibocum hep hediye dağıtıyoruz buda bizden sana diye :(
# Processed text:
# ipho 4s kampanya çok pahal be turkcell im bi kere demedi ki al iboç hep hedi dağıtıyor bu biz sa di
#
#
# Original text:
# Bende tam 00.00 kim beni dusunuyor demistim ki, turkcell mesaj atti. Canim.
# Processed text:
# be tam 00 00 kim be dusunuyor demis ki turkcell mesaj atti can
#
#
# Original text:
# benimde cok yedi turksel ya iptal ettigim servisleri tekrar actilar filan simdi vodafonedayim gayet iyi hic sorun yasamadim
# Processed text:
# ben cok yedi turksel ya iptal ettigi servis tekrar acti fila s vodafone gayet i hic sor yasamadı
#
#
# Original text:
# turkcell benden habersiz numaramı vodofonedan turkcelle taşımız sonra numaramı başka birine vermiş o.ç'ler dava açıcam ibneler:D
# Processed text:
# turkcell be habersiz numara vodofone turkcel taş sonra numara başka bir ver o ç ler dav açıca ibne d
#
#
# Original text:
# duy bunu superonline japonyada 83mbps internet 60usd ve limitsiz! kotasız!
# Processed text:
# duy p superonl japonya 83mbps internet 60usd ve limitsiz kotas
#
#
# Original text:
# alara şimdi derin nefes al, beynine oksijen gitsin ayrıca bu turkcell bana neden bokluk yaptı?
# Processed text:
# a ş der nefes al beyn oksije git ayrıç bu turkcell ba ne bokluk yap
#
#
# Original text:
# sayın ciliv bulunuduğum yerde turkcell çekmiyor. reyhanlı hataydan yazıyorum. telefonla konuşmak bizim için eziyet oluyor.
# Processed text:
# say ciliv bulunuduk yer turkcell çekmiyor reyhanlı hatay yazıyor telefo konuşmak biz iç eziyet oluyor
#
#
# Original text:
# müzik dinlerken sakin sakin arkadan birden şaaart yoook şuuurrrt yoook diye reklama başlayan turkcell ve zaytung. BSG.
# Processed text:
# müzik din sak sak arka bir şaaart yoook şuuurrrt yoook di rekla başlaya turkcell ve zaytungu bsg
#
#
# Original text:
# Bu Edge ile 3G arasinda hiz bakimindan neden hic fark yok?internet paketimden mi kaynakli acaba?
# Processed text:
# bu edge il 3g aras hiz bakim ne hic fark yok internet paket mi kaynakli acap
#
#
# Original text:
# kamil koç-türkcell 1 bilet alana 1 bilet bedava kampanyası kocaman bir kandırmacadır...AYIP !!!
# Processed text:
# kamil koç türkcell 1 bilet ala 1 bilet bedav kampanyas kocama bir kandırmaç ayip
#
#
# Original text:
# #superonline fiber internet 'in Adil Kullanım haksızlığına sessiz kalmayın. Emsal karar çıktı:   RT!
# Processed text:
# superonl fiber internet in adil kulla haksızlık sessiz kalmay emsal karar çık rt
#
#
# Original text:
# aman bunu da hizmet diye satar #Turkcell "Hayat rahatsız edilmeyince güzel" deyip yansıtır faturaya.
# Processed text:
# ama p da hizmet di satar turkcell hayat rahatsız edilmey güzel deyip yansı fatura
#
#
# Original text:
# turkcell soyguncu... Ben 6-12 ay da bır avea vodafone arası gıdıp gelıyorum kı no degıstırme fırsatlarından yararlanıyorum heheh
# Processed text:
# turkcell soyguncu ben 6 12 ay da bır avea vodafone aras gıdıp gelıyor kı no degıstırme fırsat yararlanıyor heheh
#
#
# Original text:
# #hayattansogutanseyler "Dur bir mesaj ataLim sevgiLisinden zannetsin." diye mesaj atan turkcell
# Processed text:
# hayattansogutansey dur bir mesaj atal sevgili zannet di mesaj a turkcell
#
#
# Original text:
# bu turkcell çok piç öyle böyle değil
# Processed text:
# bu turkcell çok piç ö bö değil
#
#
# Original text:
# ilişkiler karşılıklı olmalı :))1 hafta süre karşılık almazsamsilerim seni ...:)
# Processed text:
# ilişki karşılıklı olmal 1 haf sür karşılık almazsamsi se
#
#
# Original text:
# Ankara Kocatepe'de çalışıyorum. Kızılaya 500metre. Fakat altyapı nedeniyle fiber internet kullanamıyoruz.
# Processed text:
# ankar kocatep de çalışıyor kızıla 500metre fakat altyap neden fiber internet kullanamıyor
#
#
# Original text:
# sayın genel müdür, ben bir turkcell kullanıcısıyım. hatay reyhanlı da yaşamaktayım. bulunduğumuz yerde malesef turkcell
# Processed text:
# say genel mü ben bir turkcell kullanıcıs hatay reyhanlı da yaşamak bulunduk yer malesef turkcell
#
#
# Original text:
# 135 gündür hattıma tl yüklemyiormuşum. Ben fakirim Turkcell affet.
# Processed text:
# 135 g hatt tl yüklemyior ben fakir turkcell affet
#
#
# Original text:
# ipohe 4 üm ile alakalı TURKCELL ve GENPA ile büyük sıkıntılarım var. nasıl çözüm bulabiliriz?
# Processed text:
# ipoh 4 üm il alakal turkcell ve genpa il büyük sıkıntı var nasıl çöz bulabilir
#
#
# Original text:
# Tatlım senin hattın Turkcell değil mi? Ben gene sömürüldüm mesaj atarken :D
# Processed text:
# tatl se hat turkcell değil mi ben ge sömürül mesaj atar d
#
#
# Original text:
# 891.000 Abone kaybından sonra elinde ki 532 li hatları bedava dağıtmaya başladı :)) Yazık sana canım yaa! Çaresizliğin son noktası
# Processed text:
# 891 000 abone kayp sonra el ki 532 li hat bedav dağıtma başladı yazık sa ca yaa çaresizlik son noktas
#
#
# Original text:
# ya ben artık yorum yapmıyorum zaten Turkcell de msj atıp duruyo mercimek köftesi yapıcam ben cumartesiye hazırlanmam lazım :D
# Processed text:
# ya ben ar yor yapmıyor zate turkcell de msj atıp duruyo mercimek köftes yapıca ben cumartesi hazırlanma laz d
#
#
# Original text:
# Bu da alana kadar müşterimsin sonra ne halin varsa gör diyen bir anlayış vee numara taşıma numaralarına dikkat!!
# Processed text:
# bu da ala kadar müşter sonra ne hal var gör diye bir anlayış vee numar taş numara dikkat
#
#
# Original text:
# ahahaha kanka Turkcell seni rahat birakmiyo fksnfksj
# Processed text:
# ahahah kanka turkcell se rahat birakmiyo fksnfksj
#
#
# Original text:
# vay alçak turkcell
# Processed text:
# vay alçak turkcell
#
#
# Original text:
# Ve turkcell'den aldığım iPhone sağlıklı çalışmıyor.daha söyleyecek cok şey var ama daha sonra söylerim
# Processed text:
# ve turkcell den aldık ipho sağlıklı çalışmıyor dah söyleyecek cok şey var am dah sonra söy
#
#
# Original text:
# Iyiki bbm var mesaj gelince amaan turkcell den gelmistir deyip gecmiyorum
# Processed text:
# iyik bbm var mesaj gel amaan turkcell den gelmis deyip gecmiyor
#
#
# Original text:
# Baz istasyonu monte ederim sana. O turkcell açılacakk arkadaşş!
# Processed text:
# baz istasyo monte eder sa o turkcell açılacakk arkadaşş
#
#
# Original text:
# Turkcell cekmiyormu yani
# Processed text:
# turkcell cekmiyormu yani
#
#
# Original text:
# bir an evvel cevap bekliyoruz. biz burada hayatı sevdiklerimizle değil kimseyle paylaşamıyoruz.
# Processed text:
# bir an evvel cevap bekliyor biz bura hayat sevdik değil kimse paylaşamıyor
#
#
# Original text:
# istanbulda  nın çekim problemi yok,  1 GB 3G internet 14 Lira, türkcell ve vodafonun yarı fiyatı bile değil
# Processed text:
# istanbul nın çek proble yok 1 gb 3g internet 14 lira türkcell ve vodafo yar fiyat bil değil
#
#
# Original text:
# #turkcell bilgi mesajları b.kunu çıkardı ama gece gecede bu kadar yüklenilmez ki...
# Processed text:
# turkcell bilgi mesaj b k çıkar am geç gece bu kadar yüklenilmez ki
#
#
# Original text:
# Turkcell yerine ben mesaj atıcaktım ama fazla ilgiden soğursun dıye atmadım.
# Processed text:
# turkcell yer ben mesaj atıcak am faz ilgi soğur dıye atmadı
#
#
# Original text:
# 156 gundur Tl yuklemiyomusum ahahahaha artik turkcell sevgili musterimiz demiyo bana surekli anamin telefonundan Tl aktardigim icin.
# Processed text:
# 156 g tl yuklemiyomus ahahahah artik turkcell sevgil muster demiyo ba surekli anam telefon tl aktardigi iç
#
#
# Original text:
# linkteki haber i okuyun ama sonuna kadar reklam tekniğin süper turkcell ağzına sıçimmm
# Processed text:
# link haber i okuy am son kadar rekla teknik süper turkcell ağz sıçimm
#
#
# Original text:
# Turkcell'i arayıp isyan edicem şimdi.bikere olsun faturamı gelmesi gerektiği gibi yollamıyolar !
# Processed text:
# turkcell i arayıp isya edice ş biker ol fatura gelmes gerektik gip yollamıyo
#
#
# Original text:
# kontor yukle kocan olsun turkcell kanka ahahahahahaha :D
# Processed text:
# kontor yukle koca ol turkcell kanka ahahahahahah d
#
#
# Original text:
# citysdeki Turkcell tam bir dolandırıcı, iPhone4 kontratli fiyat sordum 124ten başlıyor dediler yalan yanlış bilgi veriyorlar
# Processed text:
# citys turkcell tam bir dolandırıç iphone4 kontratli fiyat sor 124ten başlıyor dedi yala yanlış bilgi veriyor
#
#
# Original text:
# Bundan sonrasını   düşünsün biz de gayet memnunuz vodofondan.
# Processed text:
# p sonra düş biz de gayet memn vodofo
#
#
# Original text:
# Şu son avea reklamından etkilendim. 4 TL'ye 100 DK Her yöne.. çok iyi tarifeler var. Turkcell yeter!
# Processed text:
# şu son avea reklam etkile 4 tl ye 100 dk her yö çok i tarife var turkcell yeter
#
#
# Original text:
# oha süperonline da bile kesiliyosa ölelim biz :(
# Processed text:
# oh süperonl da bil kesiliyos ölel biz
#
#
# Original text:
# 10 senedir turkcell iletisim merkezlernde muhattap oldgm butun erkek temsilciler  APTAL !!!
# Processed text:
# 10 se turkcell iletis merkezlern muhattap oldgm but erkek temsilci aptal
#
#
# Original text:
# kirmizidayim arammisin ulasamiooruz birbirimize malum turkcell cekmioo
# Processed text:
# kirmizida arammi ulasamioor birbir mal turkcell cekmioo
#
#
# Original text:
# lanet olsun turkcel...
# Processed text:
# lanet ol turkcel
#
#
# Original text:
# İyiki bi nar paketimiz bitti turkcell 10 saniyede 3 mesaj attı
# Processed text:
# i̇yik bi nar paket bit turkcell 10 saniye 3 mesaj at
#
#
# Original text:
# git babanı kandır
# Processed text:
# git baba ka
#
#
# Original text:
# O degilde türkcell hala beni bulupta 10 saniyede bir tweet atmadi bana bir aksilik var bu iste
# Processed text:
# o degil türkcell hal be bulup 10 saniye bir tweet atmadi ba bir aksilik var bu is
#
#
# Original text:
# "183" umarım bu rakamın sonunda "tl" ibaresi yoktur :-) Turkcell deyince aklıma sadece fatura geliyor :-)
# Processed text:
# 183 umar bu raka son tl ibares yok turkcell dey akl sadeç fatur geliyor
#
#
# Original text:
# 2 saat once kontor yukledım ama hala sms ım yenılenmedı bok ye turkcell.BOK YE
# Processed text:
# 2 saat once kontor yukledi am hal sms ım yenılenmedi bok ye turkcell bok ye
#
#
# Original text:
# Dur bi mesaj atıyımda sevdiğinden geldi sansın. -Turkcell.
# Processed text:
# dur bi mesaj atıy sevdik gel sa turkcell
#
#
# Original text:
# 10 tl mi 20 tl yapma türkcell sus bi mınakodum ya sus saat başı mesaj mı atılır
# Processed text:
# 10 tl mi 20 tl yapma türkcell sus bi mınakodu ya sus saat baş mesaj mı atılır
#
#
# Original text:
# Dur bi mesaj atalım sevgilisinden zannetsin.  -Turkcell.
# Processed text:
# dur bi mesaj atal sevgili zannet turkcell
#
#
# Original text:
# Çözüm varmı bizde hala superonline çözüm bulamadı :)
# Processed text:
# çöz varmı biz hal superonl çöz bulamadı
#
#
# Original text:
# 4 çeker diye reklam yapıp Dogan görünümlü sahin kıvamında kalansin
# Processed text:
# 4 çeker di rekla yapıp doga görünümlü sah kıvam kalans
#
#
# Original text:
# 4ceker turkcell sanirim bi tek benim oldugum yerlerde cekmiyo..
# Processed text:
# 4ceker turkcell sanir bi tek be oldugu yer cekmiyo
#
#
# Original text:
# şu 3 günlük superonline deneyimim sonucu söyleyeyim: öyle bişey yok. :)
# Processed text:
# şu 3 günlük superonl deney sonuç söyle ö bişey yok
#
#
# Original text:
# Yaptıgın ıs ıs degıl. Adam 2 ıPhone alacak dıye benden sonra gelmesıne ragmen ben bekletılıyorum suyun ısınıyor ha
# Processed text:
# yaptıgı ıs ıs degıl ada 2 ıphone alacak dıye be sonra gelmes ragme ben bekletılıyor suy ısınıyor ha
#
#
# Original text:
# Internet paketimi iptal edemiorum yardm edersnz sevinrm...
# Processed text:
# internet paket iptal edemior yardm edersnz sevinr
#
#
# Original text:
# Medyada yer alan 'olumsuz haberler klasörünün' Turkcell Genel Müdürü Süreyya Ciliv'e gösterilmediğini düşünüyorum ciddi ciddi
# Processed text:
# medya yer ala olumsuz haber klasör turkcell genel müdür süreyya ciliv e gösterilmedik düşünüyor cidi cidi
#
#
# Original text:
# bi kaç gun smsın olmayabılır turksel farkı huhu
# Processed text:
# bi kaç gun smsın olmayabılır turksel farkı huh
#
#
# Original text:
# paylasmak guzel biz onunla paylasiyrz o da bizimle cihazlari paylassa da sloganin hakkini verse turkcell ;)
# Processed text:
# paylasmak guzel biz on paylasiyrz o da biz cihaz paylas da slogan hakk ver turkcell
#
#
# Original text:
# Öf be amip Turkcell sinirlerimi bozuyosun !
# Processed text:
# öf be amip turkcell sinir bozuyo
#
#
# Original text:
# "Sevgili paylasinca guzel" ne demek Turkcell ya ?
# Processed text:
# sevgil paylasi guzel ne demek turkcell ya
#
#
# Original text:
# Mesaj alamiyor,yaklasik 2haftadir mesajciklarimi goremiyorsam bu senden vazgececegim anlamina gelebilr Turkcell.Ne merem seymissin sen boyle
# Processed text:
# mesaj alamiyor yaklasik 2haftadir mesajcik goremiyor bu se vazgececegi anlam gelebilr turkcell ne mere seymis sen boyle
#
#
# Original text:
# bu neya şimdi oldumu turkcell  yakıştımı sana :) srkn
# Processed text:
# bu neya ş oldu turkcell yakışt sa srkn
#
#
# Original text:
# kesnlikleee turkcell i kapattr hemen:)
# Processed text:
# kesnliklee turkcell i kapattr heme
#
#
# Original text:
# senden şimdi formspring'den soru ile yardım isteyecektim canısı. telefon hala kıpırdamıyor. turkcell'i dürtebilir misin aşk için?
# Processed text:
# se ş formspringi den sor il yar isteyecek canıs telefo hal kıpırdamıyor turkcell i dürtebilir mi aşk iç
#
#
# Original text:
# Brawo turkcell simdiden cekmiyor!
# Processed text:
# brawo turkcell simdi cekmiyor
#
#
# Original text:
# bi sabahta öperek uyandır be turkcell ...!
# Processed text:
# bi sabah öperek uya be turkcell
#
#
# Original text:
# Her evrakım ve ödemem tamam ama tel.kapalı.agır hastam var.LANET OLSUN SANA TURKCELL.Ölmek istiyorummmm
# Processed text:
# her evrak ve ödeme tama am tel kapal agır hasta var lanet ol sa turkcell ölmek istiyorummm
#
#
# Original text:
# cevap versene lan?
# Processed text:
# cevap verse lan
#
#
# Original text:
# su anda nisantasinda iletisim kopmus durumda haydi RT #3kelimeyle2011 Nisantasinda Turkcell Cekmiyor!!!
# Processed text:
# su an nisanta iletis kopmus dur haydi rt 3kelimeyle2011 nisanta turkcell cekmiyor
#
#
# Original text:
# Ben cevap vermiştim aynı durumu senin için dusunuyordum bu turkcell aramızı acıcak ! :)
# Processed text:
# ben cevap vermiş aynı dur se iç dusunuyor bu turkcell ara acıcak
#
#
# Original text:
# TURKCELL kullansaydın atardım sana ama turkcelli degilsin :P sözde TURKCELL de calsıyorusun :P
# Processed text:
# turkcell kullansa atar sa am turkcelli degil p söz turkcell de calsıyor p
#
#
# Original text:
# Önce bedava dakikan bitti dedin, sonra hiç eksilmeyen bir 589 dk. verdin, şimdi de 55 dakikan kaldı diyorsun.N'apmaya çalışıyorsun Turkcell?
# Processed text:
# ö bedav dakika bit dedi sonra hiç eksilmeye bir 589 dk ver ş de 55 dakika kal diyor n apma çalışıyor turkcell
#
#
# Original text:
# umursarsın dımı  ?? mesajı aldılar bence : )
# Processed text:
# umursar t mesaj al be
#
#
# Original text:
# protestom var: turkcell kasınma sabrımı tasırma
# Processed text:
# protesto var turkcell kasınma sabr tasırma
#
#
# Original text:
# Bu turkcell'in bana karşı boş olmadıgını sölemişmiydim sizi , gecenin bu saatinde hanginize böle üst üste mesaj atıyor hanginizeee :|
# Processed text:
# bu turkcell in ba karşı boş olmadıgı sölemişmi siz gece bu saat hangı böl üst üs mesaj atıyor hanginizee
#
#
# Original text:
# aralik bitiyor, turkcell dergilik uygulamasinda hala kasim sayilari duruyor yeni diye. Yakismiyor turkcele hic
# Processed text:
# aralik bitiyor turkcell dergilik uygulamas hal kas sayi duruyor ye di yakismiyor turkcel hic
#
#
# Original text:
# benden cekecegi var.
# Processed text:
# be cekecegi var
#
#
# Original text:
# amk turkcell seysi sms yapmadii hala ve arayamam mal
# Processed text:
# amk turkcell seysi sms yapmadii hal ve arayama mal
#
#
# Original text:
# Bloguma İstanbul'dan yorum bırakan Superonline müşterisi: Git kendinle kafa bul. Tabi bulman için kafa lazım, neyse..
# Processed text:
# blogu i̇stanbul dan yor bıraka superonl müşteris git kendi kaf bul tabi bulma iç kaf laz ne
#
#
# Original text:
# turkcell'e sor deki alihanın mesaj paketini neden bitirdiniz?
# Processed text:
# turkcell e sor dek aliha mesaj paket ne bitir
#
#
# Original text:
# Oha amk arkadaşla 14 dk konuştuk 6 Tl 22kurus gitmiş. Resmen soyuldum türkcell tarafından...
# Processed text:
# oh amk arkadaş 14 dk konuş 6 tl 22kurus git resme soyul türkcell taraf
#
#
# Original text:
# gerçekten ttnetden hızlıysa esos geçecem Superonline'a sinir oldum valla bu kadar yavaş olamaz birnet :S
# Processed text:
# gerçek ttnet hızlı esos geçece superonl a sinir ol val bu kadar yavaş olamaz birnet s
#
#
# Original text:
# Oha çok iyi de, Turkcell'in bahsettiği fiyat bunun çok üzerindeydi..
# Processed text:
# oh çok i de turkcell in bahsettik fiyat bu çok üzer
#
#
# Original text:
# #hayattansogutanseyler her şey süper hızlıyken bir sürü download yaparken superonline'dan "adil kullanım kotanızın..." maili gelmesi. piçler
# Processed text:
# hayattansogutansey her şey süper hızlı bir sür downloadı yapar superonl dan adil kulla kota mail gelmes piç
#
#
# Original text:
# İki sattir telefonuma msj gelip duruyo her seferinde turkcell oluyo ama bende her seferinde heyecanlanıyorum bundan sonrakine bakmıycam .P
# Processed text:
# i̇ki sattir telefon msj gelip duruyo her sefer turkcell oluyo am be her sefer heyecanlanıyor p sonrak bakmıyca p
#
#
# Original text:
# vodafone cepnet and turkcell vınn kamu :(
# Processed text:
# vodafone cepnet and turkcell vınn kamu
#
#
# Original text:
# Kımle bu kadar konusuyorsam her ay turkcell kıtlıyoooooor!
# Processed text:
# kımle bu kadar konusuyor her ay turkcell kıtlıyoooooor
#
#
# Original text:
# Levent'de Turkcell 3G yalan. Avrupanın en hızlısı buysa, tüm Avrupa'ya acıdım şimdi.
# Processed text:
# levent de turkcell 3g yala avrupa en hızlıs bu tüm avrup ya acıdı ş
#
#
# Original text:
# #turkcell biraz daha bonkör olabilirsin.
# Processed text:
# turkcell biraz dah bonkör olabilir
#
#
# Original text:
# Bugun modem icin kablo almam gerekiyodu uyumusum bi allahin kulu arayip rahatsiz etmemis her zaman hal hatir soran turkcell bile yazmamis
# Processed text:
# bugu mode iç kablo alma gerekiyodu uyumus bi allah kul arayip rahatsiz etmemis her zama hal hatir sora turkcell bil yazmamis
#
#
# Original text:
# 4 cekermish! Kactir kesiliyor konusmanin ortasinda! Yalan dolan reklam yapacaginiza azcik yatirim yapin..
# Processed text:
# 4 cekermish kactir kesiliyor konusman ortas yala dola rekla yapacagı azcik yatir yap
#
#
# Original text:
# Bu gece 23:59 da mesaj atıyımda sevdiginden sansın gerizekalı  -Turkcell
# Processed text:
# bu geç 23 59 da mesaj atıy sevdigi sa gerizekal turkcell
#
#
# Original text:
# Neyse demin sessiz telefondan, sesli telefona geçtik :)
# Processed text:
# ne de sessiz telefo sesli telefo geç
#
#
# Original text:
# hatların da sürekli kesilmesi Tcell göçügu mü yoksa iPhone kazığı mı onu daha çözemedim! Ama kabus bağlantılar!!
# Processed text:
# hat da sürekli kesilmes tcell göçügu mü yok ipho kazık mı on dah çözemedi am kabus bağlan
#
#
# Original text:
# hala çok pahalısınız
# Processed text:
# hal çok pahal
#
#
# Original text:
# hayir birde telefon edip kontrol edicez diyip hicbi gelisme olmuyo. Devlet dairesinde burokrasi sizde daha beter durumda
# Processed text:
# hayir bir telefo edip kontrol edicez diyip hicbi gelisme olmuyo devlet daire burokrasi siz dah beter dur
#
#
# Original text:
# millet telefonuna mesaj gelince ''aaa kesin o :)):))'' diye pırpırlanıyor. Ben direk '' yine Turkcell'dir amk.''
# Processed text:
# millet telefon mesaj gel aa ke o di pırpırlanıyor ben direk y turkcell dir amk
#
#
# Original text:
# İnternet paketimin bytelari yerinde sayıyor insallah turkcell sonunda öpmez beni :)
# Processed text:
# i̇nternet paket bytelar yer sayıyor insallah turkcell son öpmez be
#
#
# Original text:
# noturkcell vodafone avea :)
# Processed text:
# noturkcell vodafone avea
#
#
# Original text:
# Bu fiber Internet problemleri de cok olmaya basladi. Bir degil iki degil aliskanlik haline geldiartik #superonline
# Processed text:
# bu fiber internet problem de cok olma basladi bir degil ik degil aliskanlik hal geldiar superonl
#
#
# Original text:
# kesin olan birşey var, turkcell ve ekibinin bulaştığı tüm işlerden nefret ediyorum! FİZY'nin içine etmişler maşallah...
# Processed text:
# ke ola birşey var turkcell ve ekip bulaştık tüm iş nefret ediyor fi̇zy nin iç et maşallah
#
#
# Original text:
# Ne zaman Tweet'er yada Facebook'a girsem benim Turkcell 2G ye geçiyor.Alacam ayagımın altına.
# Processed text:
# ne zama tweet er ya facebook a gir be turkcell 2g ye geçiyor alaca ayagı alt
#
#
# Original text:
# #TURKCELL hat almayın salaklıp edipte..en büyük yanlışı yaparsınız.bildiğiniz adamı yağlı kazığa oturtuyorlar.
# Processed text:
# turkcell hat almay salaklıp edip en büyük yanlış yapar bildik ada yağlı kazık oturtuyor
#
#
# Original text:
# Mesajsa turkcell arayansa annemdir. Cok yalnizim yaa hayat cok acimasiz :(
# Processed text:
# mesaj turkcell araya anne cok yalniz yaa hayat cok acimas
#
#
# Original text:
# 4 çekmez , turkcelli pencere kenarlarında ancak acı çeker...
# Processed text:
# 4 çekmez turkcelli pencer kenar ancak aç çeker
#
#
# Original text:
# eleştirenlere inat, turkcell ile savaşınızdaki gelişmeleri tweetlemenizi bekleyenler var :)
# Processed text:
# eleştiren inat turkcell il savaş gelişme tweetleme bekleyen var
#
#
# Original text:
# twitter'ın Güzin Ablası oldunuz. Ben de Turkcell den şikayetçiyim. 2 aydır sorunumuzu gidermediler dikkat! gideremediler değil!
# Processed text:
# twitter ın güz ablas ol ben de turkcell den şikayetçi 2 ay sorun gidermedi dikkat gideremedi değil
#
#
# Original text:
# iPhone 4S Reklamında Sadece Kameraya Dikkat Çekmesi,Sanki iPhone Başka bir işe yaramıyormuş havası veriyor.Beceriksiz bi reklam
# Processed text:
# ipho 4s reklam sadeç kamera dikkat çekmes sanki ipho başka bir iş yaramıyor havas veriyor beceriksiz bi rekla
#
#
# Original text:
# İbne turkcell somurdun ulan somurdun nasıl sovuyorum şimdi sana belli değil :)
# Processed text:
# i̇bne turkcell somur ula somur nasıl sovuyor ş sa belli değil
#
#
# Original text:
# Bir uzaylı gelse de Turkcell reklamlarını izlese, müşterilerine ay sonu kol gibi fatura göndermiyor da, her sabah öperek uyandırıyor sanır:)
# Processed text:
# bir uzaylı gel de turkcell reklam izles müşteri ay so kol gip fatur göndermiyor da her sabah öperek uyandırıyor sanır
#
#
# Original text:
# ilk defa turkcell i kazıkladım ahhahaha
# Processed text:
# ilk defa turkcell i kazıkladı ahhahah
#
#
# Original text:
# en kısa süRe içiNde supeRonLine iLe oLan iLişkimi biTiriyoruM,iLanen duyRuLur..
# Processed text:
# en kıs sür iç superonl il ola ilişk bitiriyor ilane duyrulur
#
#
# Original text:
# ondan önce seninle bi turkcell hattan konuşmamız gereek geçen gün senle mesajlaştıktan sonra bütün kontrlerim bitti :D
# Processed text:
# on ö sen bi turkcell hat konuşma gereek geçe gün se mesajlaştık sonra büt kontrler bit d
#
#
# Original text:
# #hayatpaylasincaguzel 3G m calismiyor turkcell duy beni
# Processed text:
# hayatpaylasincaguzel 3g m calismiyor turkcell duy be
#
#
# Original text:
# uzgunum aslinda, nursen duy beni ve turkcell bizi ayirmasin artik, beril sende ac su telefonu soru cozucektin bana
# Processed text:
# uzgu asl nur duy be ve turkcell biz ayirma artik beril se ac su telefo sor cozucek ba
#
#
# Original text:
# canım sevgilim turkcell yeter artık terket beni! neden hep birinden msj beklediğim bi zaman da atarsın ki o msjlarını.
# Processed text:
# ca sevgil turkcell yeter ar terket be ne hep bir msj bekledik bi zama da atar ki o msjlar
#
#
# Original text:
# bir haftadir gezdigim 4. turkcel timdeym kimse modem teslimi almaya yanasmiyor beceremiyor ve istemiyolar...adami cildirttilar
# Processed text:
# bir haftadir gezdigi 4 turkcel timdeym k mode tesl alma yanasmiyor beceremiyor ve istemiyo adami cildirttilar
#
#
# Original text:
# Kimbilir kaç para olacak ki ayağına kadar getiriyorlar ama Turkcell TİM'de saatlerce bekletiyorlar bir işlem için..
# Processed text:
# kimbilir kaç par olacak ki ayak kadar getiriyor am turkcell ti̇m de saatler bekletiyor bir işle iç
#
#
# Original text:
# Kubatin sesiyle katkida bulundugu igrenc turkcell reklami kaldrilsin .
# Processed text:
# kubat se katki bulundugu igrenç turkcell rekla kaldril
#
#
# Original text:
# Bi uyarsaydın hani turkcell! :s
# Processed text:
# bi uyarsa hani turkcell s
#
#
# Original text:
# #Turkcell in Hayat Paylasinca Guzel reklami emotional selling olayini fazla abartmis!Bilincaltina calismasi gerekirken,kor goze parmak sokms
# Processed text:
# turkcell in hayat paylasi guzel rekla emotional sellingi olay faz abartmis bilincalt calismas gerekir kor goze parmak sokms
#
#
# Original text:
# 268,60 tl #turkcell faturam. Amk
# Processed text:
# 268 60 tl turkcell fatura amk
#
#
# Original text:
# Bravo   12. Katta bile cekmiyosun ya, pessss
# Processed text:
# bravo 12 kat bil cekmiyo ya pessss
#
#
# Original text:
# pis adama bulastin trcell;)
# Processed text:
# pis ada bulast trcell
#
#
# Original text:
# turkcelde bir hizmet daha ucretle sessz sedasiz bulusms oldu 7565 telesekreter aman Dkt
# Processed text:
# turkcel bir hizmet dah ucret sessz sedas bulusms ol 7565 telesekreter ama dkt
#
#
# Original text:
# ne kadar yaparsa yapsın ama Türkiye'nin internetinden bi çacık olmaz.İnternet ,teknoloji geride bi de istihbarat desen seviye 1...
# Processed text:
# ne kadar yapar yap am türki nin internet bi çacık olmaz i̇nternet teknoloj geri bi de istihbarat dese sevi 1
#
#
# Original text:
# Ohh Allaha sukur turkcell selo canlarina yilbasi reklami yapmamiss :) ne buyuk eksiklikkk anlatamam
# Processed text:
# ohh allah sukur turkcell selo can yilbas rekla yapmamiss ne buyuk eksiklikkk anlatama
#
#
# Original text:
# bu turkcell ile vodafone u baş göz etmek lazım ekürim. o zaman hep beraber kurtuluruz bunlardan :))
# Processed text:
# bu turkcell il vodafone u baş göz etmek laz ekür o zama hep beraber kurtulur bun
#
#
# Original text:
# Bir türkcell'i olarak aveanın yeni reklamına bayıldım. İyi g.t etmiş şerefsizler. :D
# Processed text:
# bir türkcell i olarak avea ye reklam bayıl i̇yi g t et şerefsiz d
#
#
# Original text:
# Bu arada 3430 omurilik felçlilerine gönderilen SMS den 2 sms bedel kesmek nedir  #turkcell
# Processed text:
# bu ara 3430 omurilik felçli gönderile sms den 2 sms bedel kesmek ne turkcell
#
#
# Original text:
# elim telefona gidiyor şunu bir arasam mı diyorum hemen turkcell mantığımı harakete geçiriyor no many :(
# Processed text:
# el telefo gidiyor ş bir arasa mı diyor heme turkcell mantık harake geçiriyor no many
#
#
# Original text:
# Laaan turkcell kendi kendine mms lerimi yiyo sikicem busefer kavga etmicem
# Processed text:
# laaan turkcell ke kendi mms ler yiyo sikice busefer kavga etmice
#
#
# Original text:
# Sabah vapurda turkcell hayat paylaşınca güzel diyerek gazete dağtyor cumhuryet hariç bence hiç de güzel değil.
# Processed text:
# sabah vapur turkcell hayat paylaş güzel diyerek gaze dağtyor cumhuryet hariç be hiç de güzel değil
#
#
# Original text:
# turkcell in onca sacmaligindan sonra vodafone tek bi kabahat islemis bise mi. Op basina koy bence :)
# Processed text:
# turkcell in o sacmaligi sonra vodafone tek bi kabahat islemis bis mi op bas koy be
#
#
# Original text:
# bu eksik bilgi sonrası maduriyetiniz için özür dileriz de yok! en azından bundan sonra bu gibi işlemlerin 'extra' ya taife dışı
# Processed text:
# bu eksik bilgi sonras maduriyet iç özür di de yok en az p sonra bu gip işle extra ya taif dış
#
#
# Original text:
# götürdüler aldıkları turkcel bayiine program çökmüş içinde demişler geri gönderdiler tel
# Processed text:
# götür aldık turkcel bayiin progra çök iç demiş ger gönder tel
#
#
# Original text:
# iPhone paket aboneliginiz iptal edilmistir.  Ne demek
# Processed text:
# ipho paket aboneligi iptal edilmis ne demek
#
#
# Original text:
# İzmir'in sokaklarında neden Turkcell'in o özel aşkımlı canımlı bitanemli kelimeleri yok lan ?
# Processed text:
# i̇zmir in sokak ne turkcell in o özel aşkımlı canımlı bitanemli kelime yok lan
#
#
# Original text:
# zamman tunelını ıptal etmek ıstıyorum yardımcı olurmusunuz
# Processed text:
# zamma tunel ıptal etmek ıstıyor yardımcı olurmu
#
#
# Original text:
# Yok yani yolda kaldık gel lastik değiş desek anlarız da zor iş bu çok basit yani turkcell seni mahvetmiş adamım
# Processed text:
# yok yani yol kal gel lastik değiş desek an da zor iş bu çok basit yani turkcell se mahvet ada
#
#
# Original text:
# 50tl yakıt alıyoruz 50dakika kazanmak için şifre yolluyoruz. Sonra mesaj geliyor arama yapıyoruz kontör gidiyor nerde kazanılan dk
# Processed text:
# 50tl yakıt alıyor 50dakik kazanmak iç şifre yolluyor sonra mesaj geliyor ara yapıyor kontör gidiyor ner kazanıla dk
#
#
# Original text:
# kapalı alanlarda sıkıntılı ama yine de işimi görüyor. Avea'nın benzer paketi Turkcell'de 55 lira.
# Processed text:
# kapal alan sıkıntıl am y de iş görüyor avea nın benzer paket turkcell de 55 lira
#
#
# Original text:
# İnsan niye kendisine kazık atanlardan vaz geçemiyor. Mesela türksel. Soktukca sokuyorlar. Vazgeçilmez. Çünkü herkes türksel.
# Processed text:
# i̇nsa ni kendi kazık atan vaz geçemiyor mesela türksel soktuk sokuyor vazgeçilmez çünkü herkes türksel
#
#
# Original text:
# Edge hizinda internetin Allah belasini versin. Turkcell duy sesimi
# Processed text:
# edge hizinda internet allah bela ver turkcell duy ses
#
#
# Original text:
# bir sure once ben de ayni durumdaydim amac nedir bilniyorum:( sonra kesildi aramalar...
# Processed text:
# bir sure once ben de ayni durumdaydı amaç ne bilniyor sonra kesil arama
#
#
# Original text:
# turkcell sasmis lan 30 tlye internet paketi mi olur
# Processed text:
# turkcell sasmis lan 30 tlye internet paket mi olur
#
#
# Original text:
# ayni sorunu ayin yedisinde bildirmistim su an cozulmedi turkcell mobil tv uygulamasinda lig tv den mac izlerken ekran
# Processed text:
# ayni sor ay yedi bildirmis su an cozulmedi turkcell mobil tv uygulamas lig tv den mac iz ekra
#
#
# Original text:
# Turkcell tam kaltak ya :D
# Processed text:
# turkcell tam kaltak ya d
#
#
# Original text:
# hahahahah :D ya yemin ederim bok gibi superonline ttnet daha iyidi :D
# Processed text:
# hahahahah d ya ye eder bok gip superonl ttnet dah iyidi d
#
#
# Original text:
# Mesajlarım neden iletilmiyor ? Ne boktan bir operatördür TURKCELL !!!
# Processed text:
# mesaj ne iletilmiyor ne bok bir operatör turkcell
#
#
# Original text:
# umarim bu mesajdan sonra bana geri donus yaparlar
# Processed text:
# umar bu mesaj sonra ba ger donus yapar
#
#
# Original text:
# cok sovdugun Tcell e geri mi dondun :D
# Processed text:
# cok sovdugu tcell e ger mi do d
#
#
# Original text:
# bırak ya bis nedir ,ara git Tcell'e de faturayı kesip göndersin hallederiz :D
# Processed text:
# bırak ya bis ne ar git tcell e de fatura kesip gönder halleder d
#
#
# Original text:
# lanet olası bir turkcell li olarak vallahi aynı nağmelerden sıkıldım lan.. üşenmesem sırf şu cıvık reklam için geçicem.
# Processed text:
# lanet olas bir turkcell li olarak vallahi aynı nağme sıkıl lan üşenmese sırf şu cıvık rekla iç geçice
#
#
# Original text:
# yalancı superonline 14 aydır sınırsız olan internt hızını düşürmeye başladılar kotasız olan bağlantımın kotasını aşmışım
# Processed text:
# yalancı superonl 14 ay sınırsız ola internt hız düşürme başladı kotas ola bağlant kota aş
#
#
# Original text:
# Ilk ve tek askim olan turkcell birak artik pesimii
# Processed text:
# ilk ve tek ask ola turkcell birak artik pesimii
#
#
# Original text:
# benim bulunduğum şehirde yok ee şansımı kayıp etmiş oluyorum:((
# Processed text:
# be bulunduk şehir yok ee şans kayıp et oluyor
#
#
# Original text:
# bukadr yuksekk fiyataa helal olsnnn kampanyaa dieee yolladnzz
# Processed text:
# bukadr yuksekk fiyataa helal olsnnn kampanyaa diee yolladnzz
#
#
# Original text:
# hayır yaaa turkcell gayet :(
# Processed text:
# hayır yaa turkcell gayet
#
#
# Original text:
# Burdan GSM operatörlerine sesleniyorum. Sen turkcell ya sen vodafone sende avea. Vapurda artik telefonlar çeksin. You can easily realize.
# Processed text:
# bur gsm operatör sesleniyor sen turkcell ya sen vodafone se avea vapur artik telefon çek you can easily realiz
#
#
# Original text:
# kendilerinden haberleri yok ki “ Turkcell Superonline bolge yetkili bayisinin beni 542 li numaradan aramasina ne demeli”
# Processed text:
# kendi haber yok ki “ turkcell superonl bolge yetkil bayi be 542 li numara aramas ne demeli”
#
#
# Original text:
# internet o kadar yavaş ki premium account'dan download yaptığım halde free user'dan bi farkım yok resmen #superonline
# Processed text:
# internet o kadar yavaş ki premium account dan downloadı yaptık halde free user dan bi fark yok resme superonl
#
#
# Original text:
# yaaaaaa tam  kızıp iphone4s almayacağım dediğim anda bu bana yapılamaz! isyan ediyorum!
# Processed text:
# yaaaaa tam kızıp iphone4s almayacak dedik an bu ba yapılamaz isya ediyor
#
#
# Original text:
# #parasineyseverelimde türkcell boş yere ikide bir mesaj göndermesin!!!
# Processed text:
# parasineyseverel türkcell boş yer iki bir mesaj gönderme
#
#
# Original text:
# 2012 ayvalık'ında turkcell çekmiyor
# Processed text:
# 2012 ayvalık ın turkcell çekmiyor
#
#
# Original text:
# 27 ağustos, Turkcell tarife bitişi. dokuz yıl önceki 250 tl yi bir türlü unutamadım. ihanet edersem belki unutabilirim
# Processed text:
# 27 ağustos turkcell tarif bitiş dok yıl öncek 250 tl yi bir türlü unutamadı ihanet eder belki unutabilir
#
#
# Original text:
# O.C. turkcell 2 senedır bana evde vınn kullandırıyosun ya ınsallah batarsın
# Processed text:
# o c turkcell 2 senedır ba ev vınn kullandırıyo ya ınsallah batar
#
#
# Original text:
# yok dava acmam terk ederim
# Processed text:
# yok dav acma terk eder
#
#
# Original text:
# Bu twitten sonra hiç dönmeyecekler ama dönmesinler,Turkcell'e aylar oldu başvuralı,hiç başvurmayanı Turkcell'e aldılar,bana hala dönmediler!
# Processed text:
# bu twit sonra hiç dönmeyecek am dönmesin turkcell e ay ol başvural hiç başvurmaya turkcell e al ba hal dönmedi
#
#
# Original text:
# lazım :)) Acun'a milyon $ verecez diye faturada bize döşüyor Turkcell :)
# Processed text:
# laz aç a milyo verecez di fatura biz döşüyor turkcell
#
#
# Original text:
# &gt;&gt;faturala, müsteri uyanık cıkıp hakkında ısrar ederse uzatmadan faturadan düş. Ben uzatmadaım, cunku Türkiye'de artık &gt;&gt;
# Processed text:
# gt gt fatural müster uyanık cıkıp hakk ısrar eder uzatma fatura düş ben uzatmadaım cunku türki de ar gt gt
#
#
# Original text:
# Bir gün turkcell şöyle bir msj atıcak; o kadar msj attım neden cevap vermiyorsun.!
# Processed text:
# bir gün turkcell şö bir msj atıcak o kadar msj at ne cevap vermiyor
#
#
# Original text:
# sozlesmesini yaptiginiz aramadiginiz , aramalarina donmediginiz aboneleriniz dahil mi buna
# Processed text:
# sozlesme yaptigi aramadigi arama donmedigi abone dahil mi p
#
#
# Original text:
# Ne yapsam istek gecersizdir diyo Twitter, Sokucam once twitter a sonra Turkcell e
# Processed text:
# ne yap istek gecersiz diyo twitter sokuca once twitter a sonra turkcell e
#
#
# Original text:
# cep telefonuma gelen mesajlardaki kıran kırana kapışma, emniyet, garanti bankası, turkcell ve beşiktaş bld arasında devam ediyor.
# Processed text:
# cep telefon gele mesaj kıra kıra kapışma emniyet garanti bankas turkcell ve beşiktaş bld ara deva ediyor
#
#
# Original text:
# 20 Mbit/s  fiber internet hattimdan hala buffer beklemeden video seyredemiyorum #rezalet #superonline
# Processed text:
# 20 mbit s fiber internet hatt hal buffer bekleme video seyredemiyor rezalet superonl
#
#
# Original text:
# ile  in yaptigi seyahat kampanyasi yerinde ama Aralik ayinda uyguladiklari sistem cok yanlis.
# Processed text:
# il in yaptigi seyahat kampanyasi yer am aralik ay uyguladik siste cok yanlis
#
#
# Original text:
# neredeyse kurulduğundan beri Turkcell kullandım AMA bu gece mobil modemle saatlerdir 56 k modem gibi bağlanınca seni terk zamadır
# Processed text:
# nere kurulduk ber turkcell kulla am bu geç mobil mode saatler 56 k mode gip bağlan se terk za
#
#
# Original text:
# 3tl durduk yere gitti Turkcell sürekli soyuyo :)
# Processed text:
# 3tl dur yer git turkcell sürekli soyuyo
#
#
# Original text:
# Beni  kucakladı. Pess!
# Processed text:
# be kucakladı pess
#
#
# Original text:
# hayat paylaşınca güzel iğrençliğinin yanında oskar alır o fasulye reklamı :)
# Processed text:
# hayat paylaş güzel iğrençlik yan oskar alır o fasulye rekla
#
#
# Original text:
# varmı turkcellde öyle temsilci hiç bir sorun çözemeyen ve çözemezde vatandası sömürmek üzerine kurulu düzende başka paket sunalım
# Processed text:
# varmı turkcell ö temsilci hiç bir sor çözemeye ve çözemez vatandas sömürmek üzer kurul düze başka paket sunal
#
#
# Original text:
# Bu ay turkcell faturamda kendi rekorumu kırdım heyoooo (ölçü kullanmak gerekirse de: kol gibi ....dıt dıt dırıt dıt.
# Processed text:
# bu ay turkcell fatura ke rekor kır heyoooo ölçü kullanmak gerekir de kol gip dıt dıt dırıt dıt
#
#
# Original text:
# bu kadarıda olmaz TURKCELL reklamında telefonla ses kalitesi yapan reklam filmi çakma çıktı :D buyrun kanıtı
# Processed text:
# bu kadarı olmaz turkcell reklam telefo ses kalites yapa rekla filmi çakma çık d buyr kanıt
#
#
# Original text:
# Superonline fiber rezalet devam ediyor
# Processed text:
# superonl fiber rezalet deva ediyor
#
#
# Original text:
# bu arada telefonumu açtım, turkcell art arda 5 mesaj attı. korkmaya başladım. ben turkcell'i arkadaş olarak sevmiştim ama:(
# Processed text:
# bu ara telefon aç turkcell art ar 5 mesaj at korkma başladı ben turkcell i arkadaş olarak sevmiş am
#
#
# Original text:
# "Ayda saaaadece 20 liraya her yöne 200 dakika artııı 100 SMS veeeee tam tamına 100 mb internet"diye reklam yapan türkcell ne kafası yaşıyor?
# Processed text:
# ay saaaadeç 20 lira her yö 200 dakik artıı 100 sms veeee tam tam 100 mb internet di rekla yapa türkcell ne kafas yaşıyor
#
#
# Original text:
# Kimselere vermediğim diğer numaramı vereyim ben sana ordan şaapalım turkcell'in boku çıktı zaten.
# Processed text:
# kimse vermedik diğer numara ver ben sa or şaapal turkcell in bok çık zate
#
#
# Original text:
# Bu turkcell harbi Pic
# Processed text:
# bu turkcell harbi pic
#
#
# Original text:
# merhabalar, şu internet paketlerinde bir düzenlemeye gitmezseniz 12 senelik bir 'Turkcell'liyi artık tamamen kaybedeceksiniz
# Processed text:
# merhaba şu internet paket bir düzenleme gitmez 12 senelik bir turkcell li ar tamame kaybedecek
#
#
# Original text:
# mecidiyeköy'de edge. asmalı'da edge. taksim göbeği 18. katta arşta yine edge. bazen çok canımı sıkıyorsun #turkcell
# Processed text:
# mecidiyeköy de edge asmal da edge taks göbek 18 kat arş y edge baze çok can sıkıyor turkcell
#
#
# Original text:
# Afedersin de turkcell cok kazik :D
# Processed text:
# afeder de turkcell cok kazik d
#
#
# Original text:
# Bu  in benle alıp veremedigi nedir ? İs yerimde çekmez evimde çekmez. Bide bangir bangir reklam yapar HD ses kalitesi diye, palavra
# Processed text:
# bu in be alıp veremedigi ne i̇s yer çekmez ev çekmez bi bangir bangir rekla yapar hd ses kalites di palavra
#
#
# Original text:
# 4 çeker 5 çeker hikayeeeeee  en az 4-5 kez cagrı merkezine telefon acmama rağmen TRABZON'da şehir merkezinde telefon cekmiyor
# Processed text:
# 4 çeker 5 çeker hikayeeeee en az 4 5 kez cagrı merkez telefo acma rağme trabzo da şehir merkez telefo cekmiyor
#
#
# Original text:
# Merhaba,ben sevgilinizden mesaj beklerken gelen Turkcell mesaji,bana ettiginiz kufurleri biliyorum...
# Processed text:
# merhap ben sevgil mesaj bek gele turkcell mesaj ba ettigi kufur biliyor
#
#
# Original text:
# Milleti kandırmayın lannn :Turkcell+Vodafone+Avea ayaginizi denk alınnn ;)
# Processed text:
# millet kandırmay lannn turkcell vodafone avea ayagı denk alınn
#
#
# Original text:
# ben 3 yıldır turkcell kullanıyorum faturamın sabıt fıyatı 80 lira ama hiç 100 un altına ınmıyor. al reyis 2000 dk vodafone mis:)
# Processed text:
# ben 3 yıl turkcell kullanıyor fatura sabıt fıyat 80 lira am hiç 100 un alt ınmıyor al reyis 2000 dk vodafone mis
#
#
# Original text:
# daha basarili musteri elinde tutma politikalari bekliyorum Turkcell den
# Processed text:
# dah basaril muster el tutma politika bekliyor turkcell den
#
#
# Original text:
# Bi sesli mesajim var diye sevinirken o da turkcell çıktı ya, ne diyim sana turkcell! Defol git turkcell!
# Processed text:
# bi sesli mesaj var di sevinir o da turkcell çık ya ne di sa turkcell defol git turkcell
#
#
# Original text:
# #turkcell iCloud reklamı yapıyor, yürü len
# Processed text:
# turkcell icloudu rekla yapıyor yür len
#
#
# Original text:
# Burdan yetkılılere seslenıorm :  se se !!! Sattıgınız blackberryı turkcel desteklıo dıosunuz turkcell en merkezı yerde cekmıo? Ne ayaksınız
# Processed text:
# bur yetkılı seslenıorm se se sattıgı blackberryı turkcel desteklıo dıo turkcell en merkezı yer cekmıo ne ayak
#
#
# Original text:
# canım #turkcell msj göndermiş, hediye kazandın msj'larına itibar etme diye. beni seviyo. (gelip konuşmasını beklesem mi ben mi teklif etsem)
# Processed text:
# ca turkcell msj gönder hedi kaza msj  itibar etme di be seviyo gelip konuşma beklese mi ben mi teklif et
#
#
# Original text:
# ayda 6tl cok, fiyati indirin, ayda 3tl yeterli, fiyati indirin abone olalim.
# Processed text:
# ay 6tl cok fiyat indir ay 3tl yeterli fiyat indir abone olal
#
#
# Original text:
# Neden durduk yere kontorlerimi yiyosun ki Turkcell?
# Processed text:
# ne dur yer kontorler yiyo ki turkcell
#
#
# Original text:
# "Sayın Süreyya Ciliv, klasör yok ama sizi olumsuz haberler konteynırına götürelim isterseniz" :))
# Processed text:
# say süreyya ciliv klasör yok am siz olumsuz haber konteynır götürel ister
#
#
# Original text:
# AYRILIK ZAMANI GELİYOR KAZIKCILAR.
# Processed text:
# ayrilik zamani geli̇yor kazikci
#
#
# Original text:
# Cumartesileri çalışmıyor musunuz?
# Processed text:
# cumartesi çalışmıyor mu
#
#
# Original text:
# allah belanı versinnn .
# Processed text:
# allah bela versinn
#
#
# Original text:
# Eğer hattınız turkcell ise yalnız değilsiniz demektir. Yoksa hergün düzenli olarak kim mesaj gönderir.
# Processed text:
# eğer hat turkcell is yalnız değil demek yok hergi düzenli olarak kim mesaj gönderir
#
#
# Original text:
# vodofone'u yurtdışında kullanmak mantıklı ben turkcell ve aveada sorun yaşayanları gördüm ama vodofoneda ben dahil sorun yaşamdm
# Processed text:
# vodofone u yurtdış kullanmak mantıklı ben turkcell ve avea sor yaşayan gör am vodofone ben dahil sor yaşamdı
#
#
# Original text:
# Bihter'cim bu Cumartesi parandan kesicem haberin olsun. Zira sana attığım SMS'in haddi hesabı yok. Turkcell bu ay beni öpecek. :)
# Processed text:
# bihter cim bu cumartes para kesice haber ol zira sa attık sms in haddi hesap yok turkcell bu ay be öpecek
#
#
# Original text:
# internet pktm bittti yeniden yaptım  cok pahalı ya hiç öğrenciyi düşünmüyo :)
# Processed text:
# internet pktm bittti yeni yap cok pahal ya hiç öğrenci düşünmüyo
#
#
# Original text:
# Turkcell gibi fiyat çekecekseniz hiç getirmeyin.
# Processed text:
# turkcell gip fiyat çekecek hiç getirmey
#
#
# Original text:
# kampanya iptali teyidi için 2 gün telefon etmesi beklenilen, sinirlenince hattı iptal etme başvurusunun 10. dk.sında arayan firma
# Processed text:
# kampanya iptal teyidi iç 2 gün telefo etmes beklenile sinirlen hat iptal etme başvuru 10 dk s araya firma
#
#
# Original text:
# Bu turkcell interneti o kadar yavas ki evin wifisi bile daha hizli
# Processed text:
# bu turkcell internet o kadar yavas ki ev wifis bil dah hizli
#
#
# Original text:
# Bugun 532 yani turkcell musteri hizmetlerinin beni 5. Aramasi bilgisayar takildi kaldi sanirim otomatige bagladi imdatt
# Processed text:
# bugu 532 yani turkcell muster hizmet be 5 aramasi bilgisayar takil kaldi sanir otomatigi bagladi imdatt
#
#
# Original text:
# erol köse:Turkcell bayisinde ''kontör bulunur'' yazısı bana Aziz Nesin'i hatirlatti..yok molped mi saticaktiniz....
# Processed text:
# erol kös turkcell bayi kontör bulunur yazıs ba aziz ne i hatirlat yok molpedi mi saticak
#
#
# Original text:
# reklamlarınızdan nefret ediyorum
# Processed text:
# reklam nefret ediyor
#
#
# Original text:
# Sevgili Turkcell dandik operatörler metroda çekiyor, Turkcell neden çekmiyor :(
# Processed text:
# sevgil turkcell dandik operatör metro çekiyor turkcell ne çekmiyor
#
#
# Original text:
# zuzu turkcell 2 gündür mesaj atmıyo kesin baska biri var :(
# Processed text:
# zuz turkcell 2 g mesaj atmıyo ke baska bir var
#
#
# Original text:
# Dur bi mesaj atalimda sevgilisinden geldi sansin -turkcell
# Processed text:
# dur bi mesaj atal sevgili gel sans turkcell
#
#
# Original text:
# hahahaha turkcell i örnek alarak sende onları soyuyorsun :D
# Processed text:
# hahahah turkcell i örnek alarak se on soyuyor d
#
#
# Original text:
# o hep yanımda oldu hıcbır zaman benı yanlız bırakmadı o  en cok duydugun ısımdı cunku o " turkcell" dı sen ne beklıyodun kı amk
# Processed text:
# o hep yan ol hıcbır zama benı yanlız bırakmadı o en cok duydugu ıs cunku o turkcell dı sen ne beklıyodu kı amk
#
#
# Original text:
# bu superonline  adil kullanım hakkı tam bi şark kurnazlığı
# Processed text:
# bu superonl adil kulla hakkı tam bi şark kurnazlık
#
#
# Original text:
# 20tl mi 100 tl yapmana gerek yok turkcell yukler yuklemez -563554 tl yapmasan yeterdi
# Processed text:
# 20tl mi 100 tl yapma gerek yok turkcell yukler yuklemez 563554 tl yapmasa yeter
#
#
# Original text:
# Bir cihaz kaydini 1,5 saatte yaparak cumle bekleyenleri cileden cikaran Kanyon #Turkcell i yilin musteri hizmetleri merkezi ilan ediyrm
# Processed text:
# bir cihaz kaydı 1 5 saatte yaparak cumle bekleyen cile cikara kanyo turkcell i yil muster hizmet merkez ila ediyr
#
#
# Original text:
# sebebiyle telefonlarında kesik olması düşünülürse insanlar adsl gunlerini arar hale geldiler. superonline = berbat alt yapı..beceriksizlik !
# Processed text:
# sebep telefon kesik olmas düşünülür in adsl gunler arar hale gel superonl berbat alt yap beceriksizlik
#
#
# Original text:
# kimse turkcell degil bari avea geceyim.
# Processed text:
# k turkcell degil bari avea geç
#
#
# Original text:
# çözüm merkezi lütfen duyun sesimi ve beni arayıp sorunumu çözün artık 48 saat olcak !!!
# Processed text:
# çöz merkez lütfe duy ses ve be arayıp sorun çöz ar 48 saat olcak
#
#
# Original text:
# Mesajim gitsin diye arkadan bi bos mesaj daha gonderiyorum tesekkurler #turkcell daha fazla ne isteybilirim kii???
# Processed text:
# mesaj git di arka bi bos mesaj dah gonderiyor tesekkur turkcell dah faz ne isteybilir kii
#
#
# Original text:
# turkcell'in tersi pistir.
# Processed text:
# turkcell in tersi pis
#
#
# Original text:
# 20 Mbit/s fiber  hattindan 1 dk lik 360p video nun gelmesi 7-8 dk suruyor. Gercekten super.. #rezalet #superonline
# Processed text:
# 20 mbit s fiber hatt 1 dk lik 360p video nun gelmes 7 8 dk suruyor gercek super rezalet superonl
#
#
# Original text:
# “RT: Turkcell'den müthiş kampanya: Siz hattınızı Turkcell'e geçirin, biz de size geçirelim.”
# Processed text:
# “rt turkcell den müthiş kampanya siz hatt turkcell e geçir biz de siz geçirel ”
#
#
# Original text:
# Ne oldu? 8 günde 10bin  çisi KORKUTTU mu seni?
# Processed text:
# ne ol 8 g 10bin çis korkut mu se
#
#
# Original text:
# ...
# Processed text:
# i̇so i̇novasyo büyük ödül nü turkcell teknoloj araştırma geliştirme i̇so i̇novasyo jüri özel ödül nü royal hal kaza
#
#
# Original text:
# abla cuma günü turkcell muzikte seni canlı canlı internettenmi dinlicez turkcell muzikte olcağını biliyorum ama nasıl olcak?
# Processed text:
# ap ç g turkcell muzik se canlı canlı internettenmi dinlicez turkcell muzik olcak biliyor am nasıl olcak
#
#
# Original text:
# keşiflerini paylasmalısın . Hayat paylasınca güzel  . Reklamı bile var :D
# Processed text:
# keşif paylasmal hayat payla güzel rekla bil var d
#
#
# Original text:
# tabi ki.. elimden ne gelirse.. hayat paylaşınca güzel.lalalalaaaaa.. :)
# Processed text:
# tabi ki el ne gelir hayat paylaş güzel lalalalaaaa
#
#
# Original text:
# yok ya iyi turkcell alistim
# Processed text:
# yok ya i turkcell alis
#
#
# Original text:
# bnce süperonline yada smileadsl yap
# Processed text:
# bnce süperonl ya smileadsl yap
#
#
# Original text:
# gördüğm en hızlı turksel müşteri temsilcisisin asıl ben teşekkür ederim :)))
# Processed text:
# gördüğm en hızlı turksel müşter temsilcis asıl ben teşekkür eder
#
#
# Original text:
# hayat paylasinca guzel ;)))
# Processed text:
# hayat paylasi guzel
#
#
# Original text:
# Biliyomusunuzzzz Turkcell oluyorummmm. Bilmessiniz tabi çünkü daha yeni karar verdimmmm.
# Processed text:
# biliyomusunuzzzz turkcell oluyorummm bilmes tabi çünkü dah ye karar verdimmm
#
#
# Original text:
# superonline :)
# Processed text:
# superonl
#
#
# Original text:
# #turkcell bana kıyak geçmiş sms paketim seneye kadar darlingler :D
# Processed text:
# turkcell ba kıyak geç sms paket sene kadar darling d
#
#
# Original text:
# eh ne demişler hayat paylaşınca güzel
# Processed text:
# eh ne demiş hayat paylaş güzel
#
#
# Original text:
# Diyarbakir'dan ayrilma vakti..Aksam yemegi ve kahvaltisi mukemmeldi..Sahneyi anlatmaya gerek yok;)Tum Turkcell ekibine tesekkurler;)
# Processed text:
# diyarbakir dan ayrilma vakti ak yemegi ve kahvaltis mukemmel sahne anlatma gerek yok tum turkcell ekip tesekkur
#
#
# Original text:
# seni seviyorum Turkcell...:) iyi ki varsın...
# Processed text:
# se seviyor turkcell i ki var
#
#
# Original text:
# internet hızım neden 8m degil ? su hızı arttırın yoksa superonline alıcam
# Processed text:
# internet hız ne 8m degil su hız arttır yok superonl alıca
#
#
# Original text:
# yazık ya :D ama bence turkcell mobil ödemeyle yemek siparis et :D
# Processed text:
# yazık ya d am be turkcell mobil ödeme yemek siparis et d
#
#
# Original text:
# gardaşcığım hayat paylaşınca güzel :):)
# Processed text:
# gardaşcık hayat paylaş güzel
#
#
# Original text:
# keske turkcell panpisim ve karsim i de yazsaydi panolara bende sana burdan yolluyorum muck :)
# Processed text:
# keske turkcell panpis ve kars i de yazsaydi pano be sa bur yolluyor muck
#
#
# Original text:
# geride kalan müzik aktivitelerinde çalıştım bugünde evden internetten izlicem.çok merak ediyorum bu güzel proje nasıl görünüyo :)
# Processed text:
# geri kala müzik aktivite çalış bugu ev internet izlice çok merak ediyor bu güzel proje nasıl görünüyo
#
#
# Original text:
# Sbh 07:30da $irkettin giri$inde elinde $ekerleriyle noel baba bizi kar$iladi:)Turkcell seni sevyorum
# Processed text:
# sbh 07 30da irket gir in el eker noel bap biz kar iladı turkcell se sevyor
#
#
# Original text:
# huaweri u8650 yani turkcell t20 o bütçe için en gelişmiş kullanışlı telefon :)
# Processed text:
# huawer u8650 yani turkcell t20 o bütçe iç en geliş kullanışlı telefo
#
#
# Original text:
# Vakit bulamama ihtimaline karşın Turkcell'den de istedim. Yarın gelecek. Hızlı okutup detayları kaçırmanı istemem :)
# Processed text:
# vakit bulama ihtimal karş turkcell den de istedi yar gelecek hızlı okutup detay kaçırma isteme
#
#
# Original text:
# Bendeniz #Turkcell e geçmiş bulunuyorum.
# Processed text:
# be turkcell e geç bulunuyor
#
#
# Original text:
# hayat paylaşınca güzel hilal ;) la la la
# Processed text:
# hayat paylaş güzel hilal la la la
#
#
# Original text:
# Turkcell i ariyorum genelde ben yia bayadir yeniliyo kendini 100mb de yapiyolar :D
# Processed text:
# turkcell i ariyor genel ben yia bayadir yeniliyo kendi 100mb de yapiyo d
#
#
# Original text:
# Büyüksün Süreyya Ciliv
# Processed text:
# büyük süreyya ciliv
#
#
# Original text:
# hoşgeldin aramıza. hayata bağlan Turkcell'le Hazal.
# Processed text:
# hoşgel ara haya bağla turkcell le hazal
#
#
# Original text:
# bugün gds sınavı var.evet var ve ben daha yeni çalısmaya basladım. Hayat paylasınca güzel
# Processed text:
# bugu gds sınav var evet var ve ben dah ye çalısma basladı hayat payla güzel
#
#
# Original text:
# ama hayat paylaşınca güzel lazım yani:D
# Processed text:
# am hayat paylaş güzel laz yani d
#
#
# Original text:
# gunaydin
# Processed text:
# gunaydı
#
#
# Original text:
# Turkcell hala "prestij" kazandıran bir marka. Onu kullanmak insanlar için hala belli bir seviyede olmakla eş.
# Processed text:
# turkcell hal prestij kazandıra bir marka on kullanmak in iç hal belli bir seviye olmak eş
#
#
# Original text:
# Iphone 4 konusunda babamın kanına girdim bugün :) Turkcell'den aldığım katalog ile yanına gidip, istiyorum bunu dedim :)
# Processed text:
# ipho 4 konu baba kan gir bugu turkcell den aldık katalogu il yan gidip istiyor p dedi
#
#
# Original text:
# Turkcell Wınn kullanmalısın :)
# Processed text:
# turkcell wınn kullanmal
#
#
# Original text:
# turkcellmuzik hoş olmuş, güzel olmuş, çok da güzel ve çok hoş olmuş
# Processed text:
# turkcellmuzik hoş ol güzel ol çok da güzel ve çok hoş ol
#
#
# Original text:
# bu tarifeyi pek beğendim:) teşekkür ederim yardımlar için tarife de bu sanırım
# Processed text:
# bu tarife pek beğe teşekkür eder yar iç tarif de bu sanır
#
#
# Original text:
# turkcell :-)
# Processed text:
# turkcell
#
#
# Original text:
# vodafone mu :/ ama herkes turkcell
# Processed text:
# vodafone mu am herkes turkcell
#
#
# Original text:
# o zaman sana bir soru. 8yıl turkcell kullanıp,bi gazla avea'ya geçtim ama şimdi yine turkcell'e geçmeyi düşünüyorum. sence?
# Processed text:
# o zama sa bir sor 8yıl turkcell kullanıp bi gaz avea ya geç am ş y turkcell e geçme düşünüyor se
#
#
# Original text:
# merhaba ben dünyanın tek sıradışı yüzüne sahib erkeği olarak turkcell kullanıyorum turkcellin kalitesi duyarlılığı tartışılmaz
# Processed text:
# merhap ben dünya tek sıradış yüz sahip erkek olarak turkcell kullanıyor turkcell kalites duyarlılık tartışılmaz
#
#
# Original text:
# "hayat paylaşınca güzel" sloganını hayata geçirmek isteyen çocuk facebook da paylaşım rekoru kırdı
# Processed text:
# hayat paylaş güzel slogan haya geçirmek isteye çocuk facebook da paylaş rekor kır
#
#
# Original text:
# saol sana da :-)
# Processed text:
# saol sa da
#
#
# Original text:
# Ekonomi sayfalarında 2011’de öne çıkan markalar belli oldu. Birinci THY, ikinci Turkcell, üçüncü Ziraat Bankası oldu.
# Processed text:
# ekono sayfa 2011’de ön çıka marka belli ol birinci thy ikinci turkcell üçüncü ziraat bankas ol
#
#
# Original text:
# turkcell in 3g si kamil kocun aptal wifi indan cok daha ii ki :)
# Processed text:
# turkcell in 3g si kamil koç aptal wif inda cok dah ii ki
#
#
# Original text:
# Ne dersen de Avea Vodofone hikaye...Turkcell gibisi yok...
# Processed text:
# ne der de avea vodofone hika turkcell gibis yok
#
#
# Original text:
# cekim gucu - turkcell = victoria melegi , vodafone = hadise.. Kapsama alani-victoria 180cm , hadise 160cm
# Processed text:
# cek guç turkcell victoria melegi vodafone hadis kapsa alani victoria 180cm hadis 160cm
#
#
# Original text:
# eger sansın varsa superonline fiber optik, yoksa zaten diğer hepsi aynı
# Processed text:
# eger sa var superonl fiber optik yok zate diğer hepsi aynı
#
#
# Original text:
# tmm tşkrler turkcell facebook sayfası
# Processed text:
# tmm tşkrler turkcell facebook sayfas
#
#
# Original text:
# son 14 ay  ondan sonra #vodafone dan kurtulacağım.. hani o reklamlarda pahalı diye salladığı şirkete gidicem #turkcell
# Processed text:
# son 14 ay on sonra vodafone dan kurtulacak hani o reklam pahal di salladık şirke gidice turkcell
#
#
# Original text:
# ahaha hadi ya öyle mi!.hatta Turkcell EMOTIONAL paketi duymuştum bir de. iltifatlar sevgi sözcükleri vs. atıyo kızlar çin ideal.
# Processed text:
# ahah hadi ya ö mi hat turkcell emotional paket duymuş bir de iltifat sevgi sözcük vs atıyo kız çin ideal
#
#
# Original text:
# yapacak bişey varsa, bulursan eğer senin durumundakileri de düşünürsün değil mi? ne de olsa hayat paylaşınca güzel :)
# Processed text:
# yapacak bişey var bulur eğer se durumundaki de düşünür değil mi ne de ol hayat paylaş güzel
#
#
# Original text:
# Bostancı Gösteri Merkezi'ne dogru yoldayiz! Konserimiz de tum sarkilar Turkcell Global Bilgi icin..Sevgiler..
# Processed text:
# bostancı göster merkez ne dogru yoldayiz konser de tum sarki turkcell global bilgi iç sevgi
#
#
# Original text:
# süperonline ım yokki 100 mbit internetim olsun:)) bizim okulda var ama 100 mbit denedim
# Processed text:
# süperonl ım yokki 100 mbit internet ol biz okul var am 100 mbit denedi
#
#
# Original text:
# İphone 4S,16 Aralık tarihinde Turkcell bayilerinde kampanyalı satışa sunulacak bilginize ...
# Processed text:
# i̇pho 4s 16 aralık tarih turkcell bayi kampanyal satış sunulacak bilgi
#
#
# Original text:
# Turkcell #PazarlamaKonferansi Charlene Li
# Processed text:
# turkcell pazarlamakonferansi charle li
#
#
# Original text:
# #encoksevdigimsey Turkcell ile hayata bağlanmak
# Processed text:
# encoksevdigimsey turkcell il haya bağlanmak
#
#
# Original text:
# Ben memnunum  'den :)
# Processed text:
# ben memn den
#
#
# Original text:
# #cokozledim  superonline ile internete bağlandığım o günleri. tek derdim ev telefonunun meşgulde olduğunu kimsenin anlamamasıydı
# Processed text:
# cokozledi superonl il interne bağlandık o gün tek der ev telefon meşgul olduk kimse anlamamas
#
#
# Original text:
# Kurumsal hat kullanmak yerine bireysel faturalı ol daha iyi valla, bireysel faturalı olsaydım Turkcell'de simdi Samsung Galaxy Note almıstım
# Processed text:
# kurumsal hat kullanmak yer bireysel fatural ol dah i val bireysel fatural olsa turkcell de s samsungu galaxy note almıs
#
#
# Original text:
# turkcell de bana çok güzel bir kız gibi geliyor vazgecemiyorum :)
# Processed text:
# turkcell de ba çok güzel bir kız gip geliyor vazgecemiyor
#
#
# Original text:
# evet bu lafım laf çakmak için yer aramak oldu:D Lafımı sadece Turkcell için geri alıyorum:D
# Processed text:
# evet bu laf laf çakmak iç yer aramak ol d laf sadeç turkcell iç ger alıyor d
#
#
# Original text:
# Saygıdeğer sayın sevgili TURKCELL ailesine en guzel dıleklerımı yolladıktan sonra isteğimin onaylanması beni sevindirmedi değil yani :D
# Processed text:
# saygıdeğer say sevgil turkcell aile en guzel dılek yolladık sonra istek onaylanmas be sevindirmedi değil yani d
#
#
# Original text:
# #turkcellfestival Harika Yorumlarından dolay model'e teşekkürler ve tabiki turkcell e :)
# Processed text:
# turkcellfestival harik yorum dolay model e teşekkür ve tabik turkcell e
#
#
# Original text:
# imza işlemez bunlara vazgeçmezler turkcel sevdalarından
# Processed text:
# imza işlemez bun vazgeçmez turkcel sevda
#
#
# Original text:
# Doğum günümü kutlayan Turkcell, Miles&amp;Smiles ve hatta Greenpeace'e bile teşekkür ediyorum, birtanesiniz :)
# Processed text:
# dok gün kutlaya turkcell miles amp smiles ve hat greenpea e bil teşekkür ediyor birta
#
#
# Original text:
# nolucak benim bu mikrofon merakim sonunda bunuda yaptim O SES TURKCELL de yarin aksam performans sergileyecegim bide kazanirsanm var ya:)
# Processed text:
# nolucak be bu mikrofo merak son bunu yapt o ses turkcell de yar ak performans sergileyecegi bi kazanirsanm var ya
#
#
# Original text:
# Kaç kez sonbohar kaçç kezz dedimm hayaaaatt ! Vodafone Freezone kullanmıyorum ama hoşuma gidiyorum.. Ben GENÇ TURKCEL. TÜRKCEL'LİNİN GÜCÜ !
# Processed text:
# kaç kez sonbohar kaçç kezz dedimm hayaaaatt vodafone freezo kullanmıyor am hoş gidiyor ben genç turkcel türkcel li̇ni̇n güç
#
#
# Original text:
# beni unutmayan tek adam turkcell
# Processed text:
# be unutmaya tek ada turkcell
#
#
# Original text:
# her yerde çeker de, bu hızla 3g hiç çekmese daha iyi. Sözleşme biter bitmez back to
# Processed text:
# her yer çeker de bu hız 3g hiç çekmes dah i sözleşme biter bitmez back to
#
#
# Original text:
# Özturkcell reklami cok iyi olmus abi ya :D suan Türkiye deee sadece 1 tane var :D
# Processed text:
# özturkcell rekla cok i olmus abi ya d suan türki dee sadeç 1 tane var d
#
#
# Original text:
# #3kelimeyle2011 basarı, performans, keyif...
# Processed text:
# 3kelimeyle2011 basar performans keyif
#
#
# Original text:
# Değer katanlar ödülü Süreyya Ciliv'e: Turkcell Genel Müdürü Süreyya Ciliv, Bahçeşehir Üniversitesi tarafından bu...
# Processed text:
# değer katan ödül süreyya ciliv e turkcell genel müdür süreyya ciliv bahçeşehir üniversites taraf bu
#
#
# Original text:
# Ohaaa bedava dk kazandim la.Canim Turkcell.(Biri bu ani not etsin,bir daha bunu ayik kafayla demem) Onumuzdeki 4 Cumartesi 60 dk'm olacak ^^
# Processed text:
# ohaa bedav dk kazandı la can turkcell bir bu ani not et bir dah p ayik kafa deme onumuzdek 4 cumartes 60 dk m olacak
#
#
# Original text:
# Ben teşekkür ederim:) hayat paylaşınca güzel desek, Turkcell sponsor olurmu acaba:)
# Processed text:
# ben teşekkür eder hayat paylaş güzel desek turkcell sponsor olurmu acap
#
#
# Original text:
# süperonline kesinllikle . .
# Processed text:
# süperonl kesinllik
#
#
# Original text:
# Internet paketim bitmedi. Ama bitmesi gerekiyodu? Buyuksun Turkcell :D
# Processed text:
# internet paket bitmedi am bitmes gerekiyodu buyuk turkcell d
#
#
# Original text:
# Tabiki hayat paylaşınca güzel :)) sohbetin çok hoşmuş yaa :)
# Processed text:
# tabik hayat paylaş güzel sohbet çok hoş yaa
#
#
# Original text:
# "hayat okudugunu paylastikca guzel" sloganiyla vapurlarda gazete dagitan turkcell e... hayyy yaşşaa len turkcell demek geldi icimden...MY
# Processed text:
# hayat okudugu paylastik guzel slogani vapur gaze dagi turkcell e hayyy yaşşaa len turkcell demek gel iç my
#
#
# Original text:
# Benim tekrar turkcell'e geçesim var. Böyle kendimi çok yalnız hissediyorum kimse mesaj atmıyo artık :(
# Processed text:
# be tekrar turkcell e geçes var bö kendi çok yalnız hissediyor k mesaj atmıyo ar
#
#
# Original text:
# bı cepten ınternete gırebılıyorum nolur bu ruya bıtmesın turkcell
# Processed text:
# bı cep ınterne gırebılıyor nolur bu ru bıtme turkcell
#
#
# Original text:
# Eğer düzenli olarak küfür etmek istiyosan ttneti seçebilirsin ben daha geçen ay superonline geçtim çok daha iyi
# Processed text:
# eğer düzenli olarak küfür etmek istiyosa ttnet seçebilir ben dah geçe ay superonl geç çok dah i
#
#
# Original text:
# Kontör aldim aninda 7 tl aldi bu turkcell ! Neyse internet paketim yenilenmis oldu iyi iyi :)
# Processed text:
# kontör aldı an 7 tl aldi bu turkcell ne internet paket yenilenmis ol i i
#
#
# Original text:
# benim için turkcell ve diğerleri.. turkcell babamın oğluymuş gibi nie savunuyosam
# Processed text:
# be iç turkcell ve diğer turkcell baba oğlu gip nie savunuyosa
#
#
# Original text:
# avea'dan gordugum 270 tl lik faturadan sonra Turkcell bana eli opulesi geldi :)
# Processed text:
# avea dan gordugu 270 tl lik fatura sonra turkcell ba el opules gel
#
#
# Original text:
# #2011 de Turkcell'de kalmaya devam ettim mesela..
# Processed text:
# 2011 de turkcell de kalma deva et mesela
#
#
# Original text:
# özturkcell abi o.
# Processed text:
# özturkcell abi o
#
#
# Original text:
# Bu arada Turkcell, caglayan adliyesinde -7'de full cekiyor, ben baska reklam bilmem. (   )
# Processed text:
# bu ara turkcell caglaya adliye 7 de full cekiyor ben baska rekla bilme
#
#
# Original text:
# Capital 500listesindeki HerBasarili 10 $irketten9'u bizimle çalisiyor TURKCELL...
# Processed text:
# capital 500listes herbasaril 10 irketten9 u biz çalisiyor turkcell
#
#
# Original text:
# turkcell kalpkalp.. .p.p =) bu  şirinlikleri hep sana yapıyo ;)
# Processed text:
# turkcell kalpkalp p p bu şirinlik hep sa yapıyo
#
#
# Original text:
# cnm ben superonline kullaniyorum kesinlikle cok hizli acaip memnunum tavsiye ediyorummm
# Processed text:
# cnm ben superonl kullaniyor kesinlik cok hizli acaip memn tavsi ediyorumm
#
#
# Original text:
# Bu mesela: SunExpress'te TURKCELL'lilere tüm iç hat uçuşlarında %50 indirim! bu gün son gun! -
# Processed text:
# bu mesela sunexpress te turkcell li tüm iç hat uçuş 50 indir bu gün son gun
#
#
# TF-IDF table saved to tfidf_output.csv
# Training TF-IDF and KNN model...
# Class: negative (Label: 1)
#   TP: 1012, FN: 275, FP: 449
# Class: neutral (Label: 2)
#   TP: 535, FN: 422, FP: 302
# Class: positive (Label: 3)
#   TP: 421, FN: 335, FP: 281
# TF-IDF ve KNN modeli başarı skoru (F1-macro): 0.5328
